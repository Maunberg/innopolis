# %%
import pandas as pd

# %% [markdown]
# С помощью read_csv читаем данные из csv-файла.

# %%
df = pd.read_csv('games.csv')
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# Используем метод info для получения общей информации о данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# *Что можно сказать об этих данных?*

# %% [markdown]
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# ## Данные

# %% [markdown]
# Столбцы, которые имеют категориальный тип данных:
# `Name, Platform, Genre, Rating`.
#
# Столбцы, которые имеют количественный тип данных:
# `Year_of_Release, NA_sales, EU_sales, JP_sales, Other_sales, Critic_Score, User_Score`.
#
# В столбцах:
# `Name, Genre, Year_of_Release, Critic_Score, User_Score,Rating ` есть пропуски.

# %% [markdown]
# ## describe

# %%
df.describe() # вывод информации о числовых столбцах
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# Метод Pandas DataFrame `describe ()` используется для вычисления некоторых статистических данных, таких как среднее значение и стандартное отклонение различных числовых значений DataFrame.

# %% [markdown]
# ## Изменение регистра в названии столбцов

# %%
df.columns # выводим названия столбцов
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %% [markdown]
# Можно изменить регистр у столбцов (также как название переменных рекомендуется использовать snake_case в названиях столбцов датасета)

# %%
df.columns = df.columns.str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Теперь все столбцы с маленькой буквы.

# %% [markdown]
# ## Пропуски

# %%
print(df.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Многие столбцы имеет пропуски, в целом обработка пропусков может быть индвидуальной и зависит от ситуации и задач, которые мы решаем.
#
# В данном наборе данных предлагается:
#
# 1 Удалить игры без года создания (**year_of_release**) (пустых данных не так много, при этом для анализа такие данные непригодны, так как не дают полной картины для анализа).
#
# 2 Также можно удалить строки с пропущенными значениями в столбцах **name** и **genre** (всего 2 строки).
#
# 3 Большое количество пропусков в столбцах **rating**, **critic_score**, **user_score** - такие данные нельзя удалять из датасета.
# При этом невозможно взять средние или медианные значения по столбцу, так как это не будет отражать реальную картину (можно в целом взять средние, но значения получатся не слишком "хорошими").
# Для восстановления таких данных необходимо учесть слишком много информации - более логично сохранить строки и обозначить, что данные для этих игр не заполнены.

# %%
df_games = df.copy() # создадим копию датасета и будем работать с ней
#метод copy создаёт копию датафрейма, в то время как простое приравнивание лишь дублирует ссылку на датафрейм.

# %%
df_games[df_games['year_of_release'].isna()] # игры в которых год не заполнен (Nan)
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
df_games[df_games['name'].isna()] # игры где название не заполнено
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
df_games[df_games['name'].isna()].index # можно удалить строки с данными индексами
# Out:
# Int64Index([659, 14244], dtype='int64')

# %%
df_games.drop(df_games[df_games['year_of_release'].isna()].index,inplace=True) # убираем игры без года создания, так как они не нужны для аналитики, а восстановить год невозможно
df_games.drop(df_games[df_games['name'].isna()].index,inplace=True) # убираем игры без названий

# %%
print(df_games.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6676
# dtype: int64

# %% [markdown]
# Столбцы, в которых много пропущенных значений заменяем конкретными значениями

# %%
df_games['rating'].fillna('не заполнен', inplace=True) # заполняем пропуски конкретным значением
df_games['critic_score'].fillna(0, inplace=True)
df_games['user_score'].fillna(0, inplace=True)

# %%
print(df_games.isna().sum())
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# ## Дубликаты

# %%
print(df_games.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Явных дубликатов нет, удалять нечего.

# %% [markdown]
# Поищем скрытые дубликаты с помощью `unique`:

# %%
col_for_dup = ['user_score', 'rating', 'platform', 'genre', 'name'] # нет смысла искать скрытые дубликаты во всех столбцах, обычно только в object и то не во всех
for col in col_for_dup:
  print('\n', col)
  print(df_games[col].unique())
# Out:
#  user_score
# ['8' 0 '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']
#
#  rating
# ['E' 'не заполнен' 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']
#
#  platform
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
#  genre
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
# ...

# %% [markdown]
# Скрытых дубликатов не обнаружено. Однако, представляет интерес, что в столбце user_score есть значение tbd, а остальные данные числовые. По сути 'tbd' означает, что сейчас идет оценивание и по факту оценки нет, в целом все tbd можно заменить значением 0

# %%
df_games.loc[df_games['user_score'] == 'tbd', 'user_score'] = 0 # "tbd" означает, что сейчас идет оценивание и по факту оценки нет, поэтому все "tbd" можно заменить
df_games['user_score'].value_counts()  # команда позволяет вывести количество каждого значения в датасете
# Out:
# 0      8981
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 1.5       2
# 0.3       2
# 1.1       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %%
df_games['rating'].value_counts() # представляет интерес в целом рассмотреть как распределены значения в столбце
# Out:
# не заполнен    6676
# E              3921
# T              2905
# M              1536
# E10+           1393
# EC                8
# K-A               3
# AO                1
# RP                1
# Name: rating, dtype: int64

# %%
df_games['critic_score'].value_counts()
# Out:
# 0.0     8461
# 70.0     252
# 71.0     248
# 75.0     240
# 80.0     235
#         ...
# 20.0       3
# 29.0       3
# 21.0       1
# 17.0       1
# 13.0       1
# Name: critic_score, Length: 82, dtype: int64

# %% [markdown]
# В critic_score - данные целые числ, .0 не обязательно добавлять, это значит, что можно преобразовать к типу int

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  object
#  10  rating           16444 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# Пропущенных значений нет, но некоторые типы данных необходимо изменить.
#
#
# *   год - целое число
# *   critic_score - целое число
# *   user_score - числовой столбец

# %%
try:
    df_games['year_of_release'] = pd.to_numeric(df_games['year_of_release'], downcast='integer') # год это целое число
    df_games['critic_score'] = pd.to_numeric(df_games['critic_score'], downcast='integer') # оценка критиков это целые числа
    df_games['user_score'] = pd.to_numeric(df_games['user_score'], downcast='float', errors ='coerce') #  столбец типа float

except:
    print('Ошибка изменения типа данных')

# %% [markdown]
# Для работы с непредсказуемым поведением данных есть конструкция try-except. Принцип работы такой: исходный код помещают в блок try. Если при выполнении кода из блока try возникнет ошибка, воспроизведётся код из блока except.

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int16
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  int8
#  9   user_score       16444 non-null  float32
#  10  rating           16444 non-null  object
# dtypes: float32(1), float64(4), int16(1), int8(1), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Часть 1
# Выполним небольшой анализ

# %% [markdown]
# Подсчитаем суммарные продажи по всему регионам и запишем данные в отдельный столбец

# %%
df_games['sum_sales'] = (df_games['na_sales'] + df_games['eu_sales']
                                   + df_games['jp_sales'] + df_games['other_sales']) #сложим данные столбцов na_sales + eu_sales+jp_sales+other_sales
df_games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score       rating  \
# 0     28.96      3.77         8.45            76         8.0            E
# 1      3.58      6.81         0.77             0         0.0  не заполнен
# 2     12.76      3.79         3.29            82         8.3            E
# 3     10.93      3.28         2.95            80         8.0            E
# 4      8.89     10.22         1.00             0         0.0  не заполнен
#
#    sum_sales
# 0      82.54
# 1      40.24
# ...

# %% [markdown]
# Посмотрим, сколько игр выпускалось в разные годы. Для этого можно построить сводную таблицу:

# %%
# Построим сводную таблицу количество игр по годам
pt_year = pd.pivot_table(df_games, index='year_of_release', values='name', aggfunc='count')
pt_year.columns = ['games_per_year'] # переименуем название столбца с количеством игр
pt_year.sort_values(by = 'games_per_year') # отсортируем по количеству игр
# Out:
#                  games_per_year
# year_of_release
# 1980                          9
# 1984                         14
# 1985                         14
# 1988                         15
# 1990                         16
# 1987                         16
# 1989                         17
# 1983                         17
# 1986                         21
# 1982                         36
# 1991                         41
# 1992                         43
# 1981                         46
# 1993                         60
# 1994                        121
# 1995                        219
# 1996                        263
# 1997                        289
# 1999                        338
# 2000                        350
# 1998                        379
# 2001                        482
# 2016                        502
# 2013                        544
# 2014                        581
# 2015                        606
# 2012                        653
# ...

# %% [markdown]
# Можно было обойтись без сводной таблицы и ипсользовать `value_counts()`

# %%
df_games['year_of_release'].value_counts().sort_values()
# Out:
# 1980       9
# 1984      14
# 1985      14
# 1988      15
# 1987      16
# 1990      16
# 1983      17
# 1989      17
# 1986      21
# 1982      36
# 1991      41
# 1992      43
# 1981      46
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1999     338
# 2000     350
# 1998     379
# 2001     482
# 2016     502
# 2013     544
# 2014     581
# 2015     606
# 2012     653
# 2004     762
# 2003     775
# 2002     829
# 2005     939
# 2006    1006
# 2011    1136
# 2007    1197
# 2010    1255
# 2009    1426
# 2008    1427
# Name: year_of_release, dtype: int64

# %% [markdown]
# Посмотрим сколько игр выпускалось для каждого жанра *(задача аналогичная верхней)*

# %%
# Построим сводную таблицу количество игр по жанрам
pt_games = pd.pivot_table(df_games, index='genre', values='name', aggfunc='count')
pt_games.columns = ['games_per_genre'] # переименуем название столбца с количеством игр
pt_games.sort_values(by = 'games_per_genre', ascending=False)# отсортируем по количеству игр по убыванию
# Out:
#               games_per_genre
# genre
# Action                   3307
# Sports                   2306
# Misc                     1721
# Role-Playing             1481
# Shooter                  1296
# Adventure                1293
# Racing                   1226
# Platform                  878
# Simulation                857
# Fighting                  837
# Strategy                  673
# Puzzle                    569

# %% [markdown]
# ### Задание для самостоятельной работы:
#
#
# **Задание 1:**  Подсчитайте количество игр по каждой платформе и выведите топ 5 платформ с наибольшим количеством игр (используйте head для вывода).

# %%
df_games.groupby('platform').count()['name'].sort_values(ascending=False).head(5)
# Out:
# platform
# PS2     2127
# DS      2121
# PS3     1306
# Wii     1286
# X360    1232
# Name: name, dtype: int64

# %%
pd.pivot_table(df_games, index='platform', values='name', aggfunc=['count']).sort_values(('count', 'name'), ascending=False).head()
# Out:
#          count
#           name
# platform
# PS2       2127
# DS        2121
# PS3       1306
# Wii       1286
# X360      1232

# %% [markdown]
# ## Часть 2
# Продолжим анализ

# %% [markdown]
# Подсчитаем суммарные продажи по каждой платформе.

# %%
# создадим сводную таблицу с суммарными продажами по платформам
pt_platform = pd.pivot_table(df_games, index=['platform'], values='sum_sales', aggfunc='sum')
pt_platform = pt_platform.sort_values('sum_sales',ascending=False)
pt_platform
# Out:
#           sum_sales
# platform
# PS2         1233.56
# X360         961.24
# PS3          931.34
# Wii          891.18
# DS           802.78
# PS           727.58
# PS4          314.14
# GBA          312.88
# PSP          289.53
# 3DS          257.81
# PC           255.76
# GB           254.43
# XB           251.57
# NES          251.05
# N64          218.01
# SNES         200.04
# GC           196.73
# XOne         159.32
# 2600          86.48
# WiiU          82.19
# PSV           53.81
# SAT           33.59
# GEN           28.35
# DC            15.95
# SCD            1.86
# NG             1.44
# WS             1.42
# TG16           0.16
# 3DO            0.10
# GG             0.04
# PCFX           0.03

# %% [markdown]
# Можно выделить платформы с наибольшими суммарными продажами (первые 5-10 платформ).

# %% [markdown]
# Отфильтруем датасет и выделим наиболее актуальный период, для этого можно использовать `query` *(новая полезная функция)*

# %%
actual_period_games_sales = df_games.query('year_of_release >= 2013') # оставим данные только за актуальный период (можно было также использовать фильтрацию датасета df_games[df_games['year_of_release']>=2013])
actual_period_games_sales
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
# создадим сводную таблицу с суммарными продажами по платформам за актуальный период
platform_actual_period = pd.pivot_table(actual_period_games_sales, index='platform',
                                     values='sum_sales', aggfunc = 'sum')
platform_actual_period.sort_values('sum_sales', ascending=False)
# Out:
#           sum_sales
# platform
# PS4          314.14
# PS3          181.43
# XOne         159.32
# 3DS          143.25
# X360         136.80
# WiiU          64.63
# PC            39.43
# PSV           32.99
# Wii           13.66
# PSP            3.50
# DS             1.54

# %% [markdown]
# Можно увидеть, что количество платформ уменьшилось.

# %% [markdown]
# Посмотрим на жанры. Создадим сводную таблицу средних продаж по жанрам игр.

# %%
pd.pivot_table(actual_period_games_sales, index='genre', values='sum_sales', aggfunc=['mean','count']).sort_values(( 'mean', 'sum_sales'), ascending=False) # также добавим столбцем с количеством игр
# Out:
#                   mean     count
#              sum_sales sum_sales
# genre
# Shooter       1.245882       187
# Sports        0.703972       214
# Platform      0.576081        74
# Role-Playing  0.499623       292
# Racing        0.469294        85
# Fighting      0.441375        80
# Action        0.420196       766
# Misc          0.405290       155
# Simulation    0.350968        62
# Puzzle        0.186471        17
# Strategy      0.180000        56
# Adventure     0.096490       245

# %% [markdown]
# Самые прибыльные жанры это **Shooter**, **Sports**, **Platform**. А также **Role-Playing**, гонки (Racing) и драки (Fighting) имеют в среднем неплохие продажи.

# %% [markdown]
# Почему надо брать средние, а не суммарные продажи (`aggfunc='sum'`). Потому что данные могут показать не совсем корректные результаты. Возьмем суммарные продажи.

# %%
pd.pivot_table(actual_period_games_sales, index='genre', values='sum_sales', aggfunc=['sum','count']).sort_values(( 'sum', 'sum_sales'), ascending=False) # также добавим столбцем с количеством игр
# Out:
#                    sum     count
#              sum_sales sum_sales
# genre
# Action          321.87       766
# Shooter         232.98       187
# Sports          150.65       214
# Role-Playing    145.89       292
# Misc             62.82       155
# Platform         42.63        74
# Racing           39.89        85
# Fighting         35.31        80
# Adventure        23.64       245
# Simulation       21.76        62
# Strategy         10.08        56
# Puzzle            3.17        17

# %% [markdown]
# Игр в стиле action очень много и суммарные продажи большие (за счет количества игр), но в среднем этот жанр на 7 месте по продажам, а не на 1-ом. Для статистики лучше брать средние значения.

# %% [markdown]
# ### Задание для самостоятельной работы:
#
#
# **Задание 2:**  Подсчитайте суммарные продажи по годам. *(по аналогии с жанрами, только используйте другой index).*

# %%
pd.pivot_table(df_games, index='year_of_release', values='sum_sales', aggfunc=['sum']).sort_values(('sum', 'sum_sales'), ascending=False)
# Out:
#                       sum
#                 sum_sales
# year_of_release
# 2008               671.50
# 2009               658.82
# 2007               604.75
# 2010               590.13
# 2006               517.71
# 2011               507.58
# 2005               457.82
# 2004               418.68
# 2002               394.97
# 2013               361.24
# 2003               357.54
# 2012               355.84
# 2014               331.53
# 2001               331.46
# 2015               267.98
# 1998               256.31
# 1999               251.11
# 2000               201.66
# 1997               201.07
# 1996               199.15
# 2016               129.94
# 1995                88.12
# 1994                79.23
# 1992                76.16
# 1989                73.45
# 1985                53.95
# 1984                50.35
# 1990                49.37
# 1988                47.21
# 1993                45.99
# 1986                37.08
# 1981                35.68
# 1991                32.23
# ...

# %%
df_games.groupby('year_of_release')['sum_sales'].sum().sort_values(ascending=False)
# Out:
# year_of_release
# 2008    671.50
# 2009    658.82
# 2007    604.75
# 2010    590.13
# 2006    517.71
# 2011    507.58
# 2005    457.82
# 2004    418.68
# 2002    394.97
# 2013    361.24
# 2003    357.54
# 2012    355.84
# 2014    331.53
# 2001    331.46
# 2015    267.98
# 1998    256.31
# 1999    251.11
# 2000    201.66
# 1997    201.07
# 1996    199.15
# 2016    129.94
# 1995     88.12
# 1994     79.23
# 1992     76.16
# 1989     73.45
# 1985     53.95
# 1984     50.35
# 1990     49.37
# 1988     47.21
# 1993     45.99
# 1986     37.08
# 1981     35.68
# 1991     32.23
# 1982     28.88
# 1987     21.70
# 1983     16.80
# 1980     11.38
# Name: sum_sales, dtype: float64

# %% [markdown]
# ## Часть 3

# %% [markdown]
# Проанализируем топ 5 жанров для каждого региона.

# %%
# найдем популярные жанры по регионам
regions = ['na_sales','eu_sales', 'jp_sales'] # регионы
for region in regions:
    print("Топ 5 жанров для", region)
    display(pd.pivot_table(actual_period_games_sales, index='genre', values= region,
                                        aggfunc='sum').sort_values(region, ascending=False).head())
# Out:
# Топ 5 жанров для na_sales
#               na_sales
# genre
# Action          126.05
# Shooter         109.74
# Sports           65.27
# Role-Playing     46.40
# Misc             27.49
# Топ 5 жанров для eu_sales
#               eu_sales
# genre
# Action          118.13
# Shooter          87.86
# Sports           60.52
# Role-Playing     36.97
# Racing           20.19
# Топ 5 жанров для jp_sales
#               jp_sales
# genre
# Role-Playing     51.04
# Action           40.49
# Misc              9.20
# Fighting          7.65
# Shooter           6.61

# %% [markdown]
# Для Европы и Северной Америки топ жанров практически не отличается за исключением 5 по популярности жанра. Для Европы - это гонки, а для Америки- misc. В Японии наиболее популярный жанр Role-Playing, а Action только на 2 месте. Предпочтения в Японии отличаются от других регионов.

# %% [markdown]
# ### Задание для самостоятельной работы:
#
#
# **Задание 3:**  Подсчитайте суммарные rating для каждого региона. *(по аналогии с жанрами, только используйте другой index).*

# %%
for i in ['na_sales',  'eu_sales', 'jp_sales', 'other_sales']:
  display(pd.pivot_table(df_games, index='rating', values=i, aggfunc='sum').sort_values(i, ascending=False).head())
  print()
# Out:
#              na_sales
# rating
# E             1274.24
# не заполнен   1225.84
# T              747.60
# M              742.89
# E10+           345.50
#              eu_sales
# rating
# E              703.87
# не заполнен    609.65
# M              480.00
# T              421.79
# E10+           183.35
#              jp_sales
# rating
# не заполнен    836.74
# E              197.96
# T              150.70
# M               63.58
# E10+            40.20
#              other_sales
# rating
# E                 231.54
# M                 176.06
# T                 152.99
# не заполнен       149.87
# E10+               71.93

# %%
for i in ['na_sales',  'eu_sales', 'jp_sales', 'other_sales']:
  print(i)
  print(df_games.groupby('rating')[i].sum().sort_values(ascending=False))
  print()
# Out:
# na_sales
# rating
# E              1274.24
# не заполнен    1225.84
# T               747.60
# M               742.89
# E10+            345.50
# K-A               2.56
# EC                1.53
# AO                1.26
# RP                0.00
# Name: na_sales, dtype: float64
#
# eu_sales
# rating
# E              703.87
# не заполнен    609.65
# M              480.00
# T              421.79
# E10+           183.35
# AO               0.61
# K-A              0.27
# EC               0.11
# RP               0.03
# Name: eu_sales, dtype: float64
#
# jp_sales
# rating
# не заполнен    836.74
# E              197.96
# T              150.70
# M               63.58
# E10+            40.20
# K-A              1.46
# AO               0.00
# EC               0.00
# RP               0.00
# Name: jp_sales, dtype: float64
#
# other_sales
# rating
# E              231.54
# M              176.06
# T              152.99
# не заполнен    149.87
# E10+            71.93
# EC               0.11
# ...

# %% [markdown]
# # Самостоятельное задние

# %%
import pandas as pd
data = pd.read_csv('clients.csv', sep=';')
data
# Out:
#        ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0    5524        1957  Graduation         Single  58138.0      0.0
# 1    2174        1954  Graduation         Single  46344.0      1.0
# 2    4141        1965  Graduation       Together  71613.0      0.0
# 3    6182        1984  Graduation       Together  26646.0      1.0
# 4    5324        1981         PhD        Married  58293.0      1.0
# ..    ...         ...         ...            ...      ...      ...
# 791  2853        1980  Graduation         Single  51766.0      1.0
# 792  2853        1980  Graduation         Single  51766.0      1.0
# 793  2853        1980  Graduation         Single  51766.0      1.0
# 794  2853        1980  Graduation         Single  51766.0      1.0
# 795  2853        1980  Graduation         Single  51766.0      1.0
#
#     Dt_Customer  NumDealsPurchases
# 0    04.09.2012                3.0
# 1    08.03.2014                2.0
# 2    21.08.2013                1.0
# ...

# %%
data.head(20)
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome Dt_Customer  \
# 0   5524        1957  Graduation         Single  58138.0      0.0  04.09.2012
# 1   2174        1954  Graduation         Single  46344.0      1.0  08.03.2014
# 2   4141        1965  Graduation       Together  71613.0      0.0  21.08.2013
# 3   6182        1984  Graduation       Together  26646.0      1.0  10.02.2014
# 4   5324        1981         PhD        Married  58293.0      1.0  19.01.2014
# 5   7446        1967      Master       Together  62513.0      0.0  09.09.2013
# 6    965        1971  Graduation       Divorced  55635.0      0.0  13.11.2012
# 7   6177        1985         PhD        Married  33454.0      1.0  08.05.2013
# 8   4855        1974         PhD       Together  30351.0      1.0  06.06.2013
# 9   5899        1950         PhD       Together   5648.0      1.0  13.03.2014
# 10  1994        1983  Graduation        MARRIED      NaN      NaN         NaN
# ...

# %% [markdown]
# Данные о клиентах магазина:
#
# 1. ID  - уникальный идентификатор клиента
# 2. Year_Birth - год рождения клиента
# 3. Education - уровень образования клиента
# 4. Marital_Status - семейное положение клиента
# 5. Income - годовой доход семьи
# 6. Kidhome - количестве детей
# 7. Dt_Customer - дата регистрации клиента в компании
# 8. NumDealsPurchases - количество покупок

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 796 non-null    int64
#  1   Year_Birth         796 non-null    int64
#  2   Education          796 non-null    object
#  3   Marital_Status     796 non-null    object
#  4   Income             784 non-null    float64
#  5   Kidhome            795 non-null    float64
#  6   Dt_Customer        795 non-null    object
#  7   NumDealsPurchases  795 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 49.9+ KB

# %% [markdown]
# Есть несколько пропусков, некоторые столбцы нужно перевести в целочисленный тип данных, Dt_Customer в datetime.

# %%
 data.describe()
# Out:
#                  ID   Year_Birth        Income     Kidhome  NumDealsPurchases
# count    796.000000   796.000000     784.00000  795.000000         795.000000
# mean    5630.133166  1968.356784   53130.07398    0.438994           2.314465
# std     3273.039715    12.022132   21818.56876    0.547252           1.941650
# min        0.000000  1899.000000    2447.00000    0.000000           0.000000
# 25%     2853.000000  1959.000000   36141.75000    0.000000           1.000000
# 50%     5563.000000  1969.500000   52372.50000    0.000000           2.000000
# 75%     8584.250000  1977.000000   69293.25000    1.000000           3.000000
# max    11191.000000  1995.000000  162397.00000    2.000000          15.000000

# %% [markdown]
#  Небольшое смещение распределения влево: Income.
#
# Выбросы по столбцу NumDealsPurchases

# %%
data['Income'].hist()
# Out:
# <AxesSubplot:>

# %%
data['NumDealsPurchases'].hist()
# Out:
# <AxesSubplot:>

# %%
data.columns = ['id', 'year_birth', 'education', 'marital_status', 'income', 'kidhome',
       'dt_customer', 'num_deals_purchases']

# %%
data.columns
# Out:
# Index(['id', 'year_birth', 'education', 'marital_status', 'income', 'kidhome',
#        'dt_customer', 'num_deals_purchases'],
#       dtype='object')

# %% [markdown]
# Мы уже проверяли данные, пропусков мало:

# %%
data.isna().sum()
# Out:
# id                      0
# year_birth              0
# education               0
# marital_status          0
# income                 12
# kidhome                 1
# dt_customer             1
# num_deals_purchases     1
# dtype: int64

# %% [markdown]
# Во всех значениях кроме Dt_Customer можно поставить ноль. Но Dt_Customer мы заполнить не можем, поэтому удалим.

# %%
data.dropna(inplace=True, subset=['dt_customer'])

# %%
data.isna().sum()
# Out:
# id                      0
# year_birth              0
# education               0
# marital_status          0
# income                 11
# kidhome                 0
# dt_customer             0
# num_deals_purchases     0
# dtype: int64

# %%
data.fillna(0, inplace=True)

# %%
data.isna().sum()
# Out:
# id                     0
# year_birth             0
# education              0
# marital_status         0
# income                 0
# kidhome                0
# dt_customer            0
# num_deals_purchases    0
# dtype: int64

# %% [markdown]
# Теперь проверим данные на наличие дубликатов.

# %%
data.duplicated().sum()
# Out:
# 4

# %% [markdown]
# Мы выявили 4 дубликата, так как там точно совпадают все строки, можем их удалить.

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
data['education'].unique()
# Out:
# array(['Graduation', 'PhD', 'Master', 'Basic'], dtype=object)

# %%
data['marital_status'].unique()
# Out:
# array(['Single', 'Together', 'Married', 'Divorced', 'SINGL', 'MARRIED',
#        'Widow', 'Alone'], dtype=object)

# %%
data['marital_status'] = data['marital_status'].apply(lambda x: x.lower())

# %%
data.loc[data['marital_status'].isin(['alone', 'singl']), 'marital_status'] = 'single'

# %%
data['marital_status'].unique()
# Out:
# array(['single', 'together', 'married', 'divorced', 'widow'], dtype=object)

# %% [markdown]
# Мы заменили все дубликаты.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 791 entries, 0 to 791
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   791 non-null    int64
#  1   year_birth           791 non-null    int64
#  2   education            791 non-null    object
#  3   marital_status       791 non-null    object
#  4   income               791 non-null    float64
#  5   kidhome              791 non-null    float64
#  6   dt_customer          791 non-null    object
#  7   num_deals_purchases  791 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 55.6+ KB

# %%
data['dt_customer'] = pd.to_datetime(data['dt_customer'],  format = '%d.%m.%Y')

# %%
data[['kidhome', 'num_deals_purchases', 'income']] = data[['kidhome', 'num_deals_purchases', 'income']].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 791 entries, 0 to 791
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   791 non-null    int64
#  1   year_birth           791 non-null    int64
#  2   education            791 non-null    object
#  3   marital_status       791 non-null    object
#  4   income               791 non-null    int64
#  5   kidhome              791 non-null    int64
#  6   dt_customer          791 non-null    datetime64[ns]
#  7   num_deals_purchases  791 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# Теперь перейдём к заданиям:

# %% [markdown]
# **Задание 1**: Группировка - тип образования по каждому семейному статусу

# %%
data.groupby(['education', 'marital_status']).count()['id']
# Out:
# education   marital_status
# Basic       divorced            1
#             married             9
#             single              1
#             together            4
# Graduation  divorced           49
#             married           170
#             single            103
#             together           96
#             widow              21
# Master      divorced           12
#             married            57
#             single             32
#             together           42
#             widow               4
# PhD         divorced           23
#             married            70
#             single             42
#             together           51
#             widow               4
# Name: id, dtype: int64

# %% [markdown]
# **Задание 2:** Сводная таблица (pivot_table) - средний доход семьи по семейному положению. Отсортировать по убыванию.

# %%
pd.pivot_table(data, index='marital_status', values='income', aggfunc='mean').sort_values('income', ascending=False)
# Out:
#                       income
# marital_status
# widow           55452.448276
# divorced        54568.164706
# together        54220.440415
# married         52206.862745
# single          49217.157303
